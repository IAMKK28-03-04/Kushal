# %% [markdown]
# <a href="https://colab.research.google.com/github/IAMKK28-03-04/Kushal/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/customers-10000 2.csv')
d=pd.read_csv('/content/customers-10000 3.csv')
print(df)
print(d)
# Out:
#       Index First Name                   Company  \
# 0         1    Heather              Mosley-David
# 1         2   Kristina  Horn, Shepard and Watson
# 2         3     Briana               Irwin-Oneal
# 3         4      Patty          Richardson Group
# 4         5   Kathleen              Carson-Burch
# ...     ...        ...                       ...
# 9995   9996     Meghan            Richardson LLC
# 9996   9997   Jeremiah               Hodge-Nixon
# 9997   9998      Peggy                  Vang LLC
# 9998   9999       Evan                 Gould Ltd
# 9999  10000    Melissa              Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# 0                           Norway           043-797-5229          26-08-20
# 1                          Andorra           932-062-1802          27-04-20
# 2                            Nepal             8352752061          22-03-22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              10000 non-null  int64
#  1   First Name         9999 non-null   object
#  2   Company            9996 non-null   object
#  3   Country            9995 non-null   object
#  4   Phone 1            9992 non-null   object
#  5   Subscription Date  9993 non-null   object
#  6   no of customers    9979 non-null   float64
#  7   Founded            9980 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 625.1+ KB

# %%
df.isna().sum()
# Out:
# Index                 0
# First Name            1
# Company               4
# Country               5
# Phone 1               8
# Subscription Date     7
# no of customers      21
# Founded              20
# dtype: int64

# %%
df_rows=df.dropna()
print("remove data object with missing values")
print(df_rows)
# Out:
# remove data object with missing values
#       Index First Name                      Company  \
# 0         1    Heather                 Mosley-David
# 1         2   Kristina     Horn, Shepard and Watson
# 3         4      Patty             Richardson Group
# 6         7     Mathew     Bender, Pittman and Kidd
# 9        10    Brendan  Schaefer, Blair and Shaffer
# ...     ...        ...                          ...
# 9995   9996     Meghan               Richardson LLC
# 9996   9997   Jeremiah                  Hodge-Nixon
# 9997   9998      Peggy                     Vang LLC
# 9998   9999       Evan                    Gould Ltd
# 9999  10000    Melissa                 Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# 0                           Norway           043-797-5229          26-08-20
# 1                          Andorra           932-062-1802          27-04-20
# ...

# %%
df_columns=df.dropna(axis=1)
print("remove missing values with attribute")
print(df_columns)
# Out:
# remove missing values with attribute
#       Index
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ...     ...
# 9995   9996
# 9996   9997
# 9997   9998
# 9998   9999
# 9999  10000
#
# [10000 rows x 1 columns]

# %%
df.fillna(0)
# Out:
#       Index First Name                   Company  \
# 0         1    Heather              Mosley-David
# 1         2   Kristina  Horn, Shepard and Watson
# 2         3     Briana               Irwin-Oneal
# 3         4      Patty          Richardson Group
# 4         5   Kathleen              Carson-Burch
# ...     ...        ...                       ...
# 9995   9996     Meghan            Richardson LLC
# 9996   9997   Jeremiah               Hodge-Nixon
# 9997   9998      Peggy                  Vang LLC
# 9998   9999       Evan                 Gould Ltd
# 9999  10000    Melissa              Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# 0                           Norway           043-797-5229          26-08-20
# 1                          Andorra           932-062-1802          27-04-20
# 2                            Nepal             8352752061          22-03-22
# ...

# %%
df_fill=df.fillna(df.mean(numeric_only=True))
print("impute and estimate with missing values")
print(df_fill)
# Out:
# impute and estimate with missing values
#       Index First Name                   Company  \
# 0         1    Heather              Mosley-David
# 1         2   Kristina  Horn, Shepard and Watson
# 2         3     Briana               Irwin-Oneal
# 3         4      Patty          Richardson Group
# 4         5   Kathleen              Carson-Burch
# ...     ...        ...                       ...
# 9995   9996     Meghan            Richardson LLC
# 9996   9997   Jeremiah               Hodge-Nixon
# 9997   9998      Peggy                  Vang LLC
# 9998   9999       Evan                 Gould Ltd
# 9999  10000    Melissa              Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# 0                           Norway           043-797-5229          26-08-20
# 1                          Andorra           932-062-1802          27-04-20
# 2                            Nepal             8352752061          22-03-22
# ...

# %%
df.fillna(df.median(numeric_only=True))
# Out:
#       Index First Name                   Company  \
# 0         1    Heather              Mosley-David
# 1         2   Kristina  Horn, Shepard and Watson
# 2         3     Briana               Irwin-Oneal
# 3         4      Patty          Richardson Group
# 4         5   Kathleen              Carson-Burch
# ...     ...        ...                       ...
# 9995   9996     Meghan            Richardson LLC
# 9996   9997   Jeremiah               Hodge-Nixon
# 9997   9998      Peggy                  Vang LLC
# 9998   9999       Evan                 Gould Ltd
# 9999  10000    Melissa              Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# 0                           Norway           043-797-5229          26-08-20
# 1                          Andorra           932-062-1802          27-04-20
# 2                            Nepal             8352752061          22-03-22
# ...

# %%
df.interpolate()
# Out:
# <ipython-input-10-11c47216a02d>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#       Index First Name                   Company  \
# 0         1    Heather              Mosley-David
# 1         2   Kristina  Horn, Shepard and Watson
# 2         3     Briana               Irwin-Oneal
# 3         4      Patty          Richardson Group
# 4         5   Kathleen              Carson-Burch
# ...     ...        ...                       ...
# 9995   9996     Meghan            Richardson LLC
# 9996   9997   Jeremiah               Hodge-Nixon
# 9997   9998      Peggy                  Vang LLC
# 9998   9999       Evan                 Gould Ltd
# 9999  10000    Melissa              Burns-Holden
#
#                            Country                Phone 1 Subscription Date  \
# ...

# %%
from scipy.stats import zscore
zscore=(numeric_df - numeric_df.mean()) / numeric_df.std()
outliers=[abs(zscore)>3]
print("outliers:",outliers)
# Out:
# outliers: [      Index  no of customers  Founded
# 0     False            False    False
# 1     False            False     True
# 2     False             True    False
# 3     False             True    False
# 4     False            False     True
# ...     ...              ...      ...
# 9995  False            False    False
# 9996  False            False    False
# 9997  False            False    False
# 9998  False            False    False
# 9999  False            False    False
#
# [10000 rows x 3 columns]]

# %%
q1=numeric_df.quantile(0.25)
q3=numeric_df.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
outliers=numeric_df[(numeric_df < lower) | (numeric_df > upper)]
print(outliers)
# Out:
#       Index  no of customers     Founded
# 0       NaN              NaN         NaN
# 1       NaN              NaN   7457575.0
# 2       NaN       75757575.0         NaN
# 3       NaN        5757575.0         NaN
# 4       NaN              NaN  75575775.0
# ...     ...              ...         ...
# 9995    NaN              NaN         NaN
# 9996    NaN              NaN         NaN
# 9997    NaN              NaN         NaN
# 9998    NaN              NaN         NaN
# 9999    NaN              NaN         NaN
#
# [10000 rows x 3 columns]

# %%
numeric_df=df.select_dtypes(include='number')
lower_cap=10
upper_cap=100
replace_df=numeric_df.clip(lower=lower_cap, upper=upper_cap)
print(replace_df)
# Out:
#       Index  no of customers  Founded
# 0        10            100.0    100.0
# 1        10            100.0    100.0
# 2        10            100.0      NaN
# 3        10            100.0    100.0
# 4        10              NaN    100.0
# ...     ...              ...      ...
# 9995    100            100.0    100.0
# 9996    100            100.0    100.0
# 9997    100            100.0    100.0
# 9998    100            100.0    100.0
# 9999    100            100.0    100.0
#
# [10000 rows x 3 columns]

# %%
log_transform=np.log(numeric_df)
print(log_transform)
# Out:
#          Index  no of customers    Founded
# 0     0.000000         8.970940   7.594884
# 1     0.693147         8.037543  15.824741
# 2     1.098612        18.143049        NaN
# 3     1.386294        15.566027   7.594884
# 4     1.609438              NaN  18.140646
# ...        ...              ...        ...
# 9995  9.209940         9.188810   7.607381
# 9996  9.210040         8.421783   7.609862
# 9997  9.210140         8.824237   7.592366
# 9998  9.210240         7.918265   7.588324
# 9999  9.210340         8.429018   7.604396
#
# [10000 rows x 3 columns]

# %%
numeric_df[((abs(numeric_df - numeric_df.mean()) / numeric_df.std()) < 3)]
# Out:
#       Index  no of customers  Founded
# 0         1           7871.0   1988.0
# 1         2           3095.0      NaN
# 2         3              NaN      NaN
# 3         4              NaN   1988.0
# 4         5              NaN      NaN
# ...     ...              ...      ...
# 9995   9996           9787.0   2013.0
# 9996   9997           4545.0   2018.0
# 9997   9998           6797.0   1983.0
# 9998   9999           2747.0   1975.0
# 9999  10000           4578.0   2007.0
#
# [10000 rows x 3 columns]
